# %%
import logging
from utils import logging as lg
lg.set_logging(logging.ERROR)


from skimage.measure import block_reduce
import numpy as np

import logging


from notebook_utils import plot 

from model import base, provider, heatmap_evaluation
import config
import matplotlib.pyplot as plt
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
from utils import data_provider

# %%
dataset = {
    'mnist': data_provider.MNISTData(dir_path='../data/mnist'),
    'fashion-mnist': data_provider.FashionMNISTData(dir_path='../data/fashion-mnist'),
    'ufi-cropped': data_provider.UFICroppedData(dir_path='../data/ufi-cropped'),
    'mnist-3-digits': data_provider.MNIST3DigitsData(dir_path='../data/mnist'),
    'mnist-3-digits-maj': data_provider.MNIST3DigitsWithMajorityData(dir_path='../data/mnist'),
    'fashion-mnist-3-items': data_provider.MNIST3DigitsData(dir_path='../data/fashion-mnist')
}

# %%
methods=list(filter(lambda x: x != 'random', config.METHODS))
verbose=False

# %%
plot.plot_relevance_methods("../experiment-results/shallow_2_levels/shallow_2_levels-mnist-seq-1---2018-02-11--21-05-04", dataset['mnist'], methods=methods, verbose=verbose)

# %%
plot.plot_relevance_methods("../experiment-results/shallow_2_levels/shallow_2_levels-mnist-seq-4---2018-02-11--21-03-18", dataset['mnist'], methods=methods, verbose=verbose)

# %%
plot.plot_relevance_methods("../experiment-results/shallow_2_levels/shallow_2_levels-mnist-seq-7---2018-02-11--21-05-33", dataset['mnist'], methods=methods, verbose=verbose)

# %%
plot.plot_relevance_methods("../experiment-results/shallow_2_levels/shallow_2_levels-mnist-3-digits-seq-12---2018-02-11--22-46-42", dataset['mnist-3-digits'], methods=methods, verbose=verbose)

# %%
plot.plot_relevance_methods("../experiment-results/shallow_2_levels/shallow_2_levels-fashion-mnist-3-items-seq-12---2018-02-12--06-58-53", dataset['fashion-mnist-3-items'], methods=methods, verbose=verbose)

# %% [markdown]
# # Lenet

# %%
# plot.plot_relevance_methods("../final-models/lenet-fashion-mnist", dataset['fashion-mnist'])

# %%
# plot.plot_relevance_methods("../final-models/lenet-mnist", dataset['mnist'])

# %% [markdown]
# # Shallow 2 Levels

# %%
# plot.plot_relevance_methods("../experiment-results/shallow_2_levels/shallow_2_levels-mnist-seq-1---2018-02-11--20-09-47", dataset['mnist'], methods=['sensitivity', 'simple_taylor', 'guided_backprop'])

# %% [markdown]
# # MNIST 3 digits with majority

# %%
plot.plot_relevance_methods("../experiment-results/3-items-maj-dataset/aws-training/s2_network-mnist-3-digits-maj-seq-12---2018-02-14--21-13-53", dataset['mnist-3-digits-maj'], methods=methods, verbose=verbose)

# %%
plot.plot_relevance_methods("../experiment-results/mnist-3-digits/s3_network-mnist-3-digits-maj-seq-12---2018-02-14--21-28-40", dataset['mnist-3-digits-maj'], methods=methods, verbose=verbose)
