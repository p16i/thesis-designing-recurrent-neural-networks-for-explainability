# %%
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

import logging
from utils import logging as lg
lg.set_logging(logging.ERROR)

from model import provider
from utils import data_provider



import numpy as np

# %%
dataset = {
    'mnist': data_provider.MNISTData(dir_path='../data/mnist'),
    'fashion-mnist': data_provider.FashionMNISTData(dir_path='../data/fashion-mnist'),
    'ufi-cropped': data_provider.UFICroppedData(dir_path='../data/ufi-cropped')
}

# %%
def count_positive_relevances(model_path):
    model_obj = provider.load(model_path)
    dn = model_obj._.dataset
    x = dataset[dn].test2d.x
    y = dataset[dn].test2d.y
    
    rr_inputs = np.zeros((x.shape[0], model_obj.architecture.recur))
    
    with model_obj.get_session() as sess:
        y_pred, y_pred_y_target = sess.run([model_obj.dag.y_pred, model_obj.dag.y_pred_y_target], feed_dict= {
            model_obj.dag.x: x,
            model_obj.dag.y_target: y,
            model_obj.dag.rx: rr_inputs,
            model_obj.dag.keep_prob: 1
        })
        
    relevance = np.sum(y_pred_y_target, axis=1)
    print('Positive relevance for model %s' % model_obj._.experiment_name)
    
    idc = np.argwhere(relevance < 0)
    idc2 = np.argwhere(np.max(y_pred, axis=1) < 0)
    print('there are %d negative relevance (y_pred_y_target)' % len(idc))
    print('and there are %d negative relevance (max y_pred)' % len(idc2))
    for i in idc[:10]:
        print('------')
        print('target %d -> pred  %d' % (np.argmax(y[i]), np.argmax(y_pred[i])))
        print('y_pred', y_pred[i, :][0])
        print('relevance from y_target', np.sum(y_pred_y_target[i, :][0]))
        print('relevance from y_pred', np.max(y_pred[i, :][0]))
        print('======')
    print('relevance >= 0 : %f' % (np.mean(relevance >= 0)))

# %%
count_positive_relevances('../experiment-results/aws-training/convdeep_4l_artificial_output-fashion-mnist-seq-1---2018-01-25--11-32-53')
# Out:
# (<tf.Tensor 'strided_slice_1:0' shape=() dtype=int32>, 1)
# (?, 11)
# Positive relevance for model convdeep_4l_artificial_output-fashion-mnist-seq-1---2018-01-25--11-32-53
# there are 9 negative relevance (y_pred_y_target)
# and there are 0 negative relevance (max y_pred)
# ------
# target 8 -> pred  2
# y_pred [ 1.12723207  0.94349825  2.79700756 -1.61281919  0.95230627  0.44512999
#   2.04566336 -2.30197406 -0.09219295 -2.29113793]
# relevance from y_target -0.0921929
# relevance from y_pred 2.79701
# ======
# ------
# target 3 -> pred  8
# y_pred [ 1.03394842 -1.48387778 -1.03439963 -2.56151509 -1.77318501  0.48712814
#   4.29759789 -2.21044707  4.61145544 -0.38979101]
# relevance from y_target -2.56152
# relevance from y_pred 4.61146
# ======
# ------
# target 8 -> pred  1
# y_pred [ 0.46435371  7.25705814  1.2465378   3.93458104  5.6124649  -4.60976553
#  -0.29691213 -4.93810272 -0.79480761 -8.78983116]
# relevance from y_target -0.794808
# relevance from y_pred 7.25706
# ======
# ------
# target 4 -> pred  6
# y_pred [ 9.12425518 -7.03998995  5.78646994 -5.07782555 -1.58345044 -1.24653828
#   9.74970531 -8.42230129  4.7874198  -8.31180573]
# relevance from y_target -1.58345
# relevance from y_pred 9.74971
# ======
# ------
# target 8 -> pred  6
# y_pred [ -3.95668125e+00  -3.18395090e+00   3.13266587e+00   2.24246001e+00
#    4.86098576e+00  -3.37338948e+00   5.10293293e+00  -4.14059210e+00
#   -3.01214680e-03  -3.39606833e+00]
# relevance from y_target -0.00301215
# relevance from y_pred 5.10293
# ======
# ------
# target 9 -> pred  6
# y_pred [ 2.33691025 -0.26790664  2.94898319 -1.99180079 -1.64305234  1.26780319
#   4.42533112 -4.16655159  0.262952   -0.54567373]
# relevance from y_target -0.545674
# relevance from y_pred 4.42533
# ======
# ------
# target 1 -> pred  8
# y_pred [ 3.43258095 -0.09415939 -0.04604051 -4.88284874 -1.11784744 -0.42672652
#   4.64665508 -3.7738688   5.96126986 -3.03797603]
# relevance from y_target -0.0941594
# relevance from y_pred 5.96127
# ======
# ------
# target 3 -> pred  6
# y_pred [ 4.1356554  -4.19005299  2.75000978 -0.12698483  3.34450293 -5.88031054
#   7.40215254 -6.88650084 -3.36204815 -6.1076045 ]
# relevance from y_target -0.126985
# relevance from y_pred 7.40215
# ======
# ------
# target 1 -> pred  6
# y_pred [ 2.83145189 -0.54550058  0.73556709 -0.15424116  3.49427104 -4.67758989
#   4.71901274 -5.73765326 -1.94954431 -5.15666962]
# relevance from y_target -0.545501
# relevance from y_pred 4.71901
# ======
# relevance >= 0 : 0.999100

# %%
count_positive_relevances('../final-models/convdeep_4l_network-fashion-mnist-seq-1')
# Out:
# Positive relevance for model convdeep_4l_network-fashion-mnist-seq-1---2017-12-31--15-51-33
# there are 30 negative relevance (y_pred_y_target)
# and there are 0 negative relevance (max y_pred)
# ------
# target 3 -> pred  6
# y_pred [ 4.48649597 -5.7092967  -1.08241236 -1.39311039 -4.91674089 -6.93967581
#   4.53562546 -5.76376724 -3.02578592 -6.27914953]
# relevance from y_target -1.39311
# relevance from y_pred 4.53563
# ======
# ------
# target 6 -> pred  3
# y_pred [ 1.72274578 -6.4026103   0.51694286  6.99711514  1.45467842 -7.86325216
#  -1.16246235 -8.39609432 -5.57501698 -8.22821712]
# relevance from y_target -1.16246
# relevance from y_pred 6.99712
# ======
# ------
# target 8 -> pred  6
# y_pred [-0.81181693 -0.71073139 -0.75521129 -0.69408196 -0.72424281 -0.23290376
#   0.42867506 -1.93395734 -1.12925744 -0.52350616]
# relevance from y_target -1.12926
# relevance from y_pred 0.428675
# ======
# ------
# target 1 -> pred  3
# y_pred [ -3.02982211e+00  -2.06510991e-01  -1.73223495e+00   1.20779552e+01
#   -1.96934855e+00  -1.00249920e+01   1.53498538e-03  -9.12166691e+00
#   -7.13881922e+00  -8.08510685e+00]
# relevance from y_target -0.206511
# relevance from y_pred 12.078
# ======
# ------
# target 4 -> pred  6
# y_pred [-1.75251985 -2.8163414   0.75854814 -4.54417086 -1.57980025 -6.29168224
#   5.81008005 -8.7599926   0.74059719 -4.57549524]
# relevance from y_target -1.5798
# relevance from y_pred 5.81008
# ======
# ------
# target 8 -> pred  4
# y_pred [-0.37736472 -8.54850388  2.42453551  0.7679413   3.50772238 -6.1890974
#  -0.13658427 -8.66833115 -0.13919203 -8.71112156]
# relevance from y_target -0.139192
# relevance from y_pred 3.50772
# ======
# ------
# target 2 -> pred  4
# y_pred [-3.61460638 -7.12847948 -0.61414057  3.91710353  5.02026415 -6.64066935
#   3.46126556 -7.26256847 -4.54113817 -7.39304495]
# relevance from y_target -0.614141
# relevance from y_pred 5.02026
# ======
# ------
# target 6 -> pred  4
# y_pred [-1.29455125  0.56569135  1.87592876  1.653777    3.94388986 -8.44298267
#  -0.63556343 -7.34366655 -5.08300781 -6.11118746]
# relevance from y_target -0.635563
# relevance from y_pred 3.94389
# ======
# ------
# target 3 -> pred  6
# y_pred [ 2.67069173 -7.38517332  0.65408415 -1.72013295 -4.09413433 -5.48523951
#   2.98512077 -6.87356663  1.37589228 -7.64516973]
# relevance from y_target -1.72013
# relevance from y_pred 2.98512
# ======
# ------
# target 8 -> pred  1
# y_pred [-0.14393827  7.68512392 -2.52095127  0.22917055 -0.48453546 -7.12866116
#  -0.73194474 -7.60956335 -3.41775918 -6.57986975]
# relevance from y_target -3.41776
# relevance from y_pred 7.68512
# ======
# relevance >= 0 : 0.997000

# %%
count_positive_relevances('../final-models/convdeep_4l_network-fashion-mnist-seq-4')
# Out:
# Positive relevance for model convdeep_4l_network-fashion-mnist-seq-4---2017-12-31--02-37-42
# there are 63 negative relevance (y_pred_y_target)
# and there are 0 negative relevance (max y_pred)
# ------
# target 3 -> pred  0
# y_pred [  5.10755062  -5.0253973   -0.49860069  -0.3703216   -3.0950892
#   -7.98560715   3.62240696  -8.40043545  -4.46741915 -11.0057106 ]
# relevance from y_target -0.370322
# relevance from y_pred 5.10755
# ======
# ------
# target 6 -> pred  3
# y_pred [  0.03645536  -1.52355778  -0.38996473   4.92469931  -0.89545685
#   -8.35720634  -0.13512276  -8.95652485  -5.92859173 -10.07127476]
# relevance from y_target -0.135123
# relevance from y_pred 4.9247
# ======
# ------
# target 8 -> pred  2
# y_pred [ 0.41945598 -3.54612875  2.93324971 -3.31240726  0.32405964 -5.57853413
#   1.16746211 -7.88873959 -1.78173053 -6.25149441]
# relevance from y_target -1.78173
# relevance from y_pred 2.93325
# ======
# ------
# target 8 -> pred  5
# y_pred [-3.30727601 -7.35482645 -8.09138489 -9.56298351 -9.37094879  5.51894045
#  -5.60996819 -0.34327939 -0.27045226  2.67208433]
# relevance from y_target -0.270452
# relevance from y_pred 5.51894
# ======
# ------
# target 1 -> pred  3
# y_pred [ -2.27854729  -0.21299987  -2.17199373   8.19341946  -0.86051482
#  -12.63740253  -0.07465135 -14.3672657   -6.99403429 -15.45842743]
# relevance from y_target -0.213
# relevance from y_pred 8.19342
# ======
# ------
# target 4 -> pred  2
# y_pred [-0.22241078 -3.1445756   2.68064642 -3.71891975 -0.39363396 -8.38196564
#   1.22773135 -7.08632135 -1.7902292  -4.34323549]
# relevance from y_target -0.393634
# relevance from y_pred 2.68065
# ======
# ------
# target 3 -> pred  0
# y_pred [  9.30988216 -10.18483829   0.75065356  -2.63556528  -5.22554779
#  -12.43311024   4.41136456 -16.66158485  -6.49598455 -19.67517853]
# relevance from y_target -2.63557
# relevance from y_pred 9.30988
# ======
# ------
# target 8 -> pred  5
# y_pred [-3.8953023  -5.71624517 -5.57457209 -7.92278576 -6.60553265  6.29067755
#  -4.88107586  0.812159   -2.10487247  0.46184319]
# relevance from y_target -2.10487
# relevance from y_pred 6.29068
# ======
# ------
# target 1 -> pred  3
# y_pred [  0.75235158  -0.80663818  -1.80397224   5.40450048  -1.90483284
#   -9.05363464  -0.37823233 -10.33397675  -5.13433981 -12.08637047]
# relevance from y_target -0.806638
# relevance from y_pred 5.4045
# ======
# ------
# target 1 -> pred  3
# y_pred [ 0.24080274 -0.20159663 -0.32322067  1.58271039 -1.27259052 -3.14396811
#   0.99059546 -4.33585739 -3.41376591 -4.84744167]
# relevance from y_target -0.201597
# relevance from y_pred 1.58271
# ======
# relevance >= 0 : 0.993700

# %%
count_positive_relevances('../final-models/convdeep_4l_network-fashion-mnist-seq-7')
# Out:
# Positive relevance for model convdeep_4l_network-fashion-mnist-seq-7---2017-12-31--03-21-56
# there are 37 negative relevance (y_pred_y_target)
# and there are 0 negative relevance (max y_pred)
# ------
# target 8 -> pred  2
# y_pred [-0.02716491 -1.35327923  2.94288564 -0.8029393   1.15762138 -5.23458719
#   1.82087898 -7.82125092 -2.10107684 -5.55003071]
# relevance from y_target -2.10108
# relevance from y_pred 2.94289
# ======
# ------
# target 1 -> pred  6
# y_pred [ 1.93924224 -1.06769657 -0.14296976  0.91294503 -0.9092232  -4.17715406
#   2.62155604 -5.20541    -2.13040304 -4.85550117]
# relevance from y_target -1.0677
# relevance from y_pred 2.62156
# ======
# ------
# target 4 -> pred  2
# y_pred [-0.01500711 -1.58322775  1.98990333 -2.87291718 -0.50880027 -6.0669055
#   1.47823894 -6.87072659 -1.32242978 -4.47522116]
# relevance from y_target -0.5088
# relevance from y_pred 1.9899
# ======
# ------
# target 3 -> pred  0
# y_pred [  6.4049859   -7.67512369  -0.76289636  -1.3775773   -4.74064445
#   -7.13936806   4.05449438 -11.38389492  -1.96938002 -11.32603073]
# relevance from y_target -1.37758
# relevance from y_pred 6.40499
# ======
# ------
# target 0 -> pred  4
# y_pred [-0.64774221 -2.18944001  0.68828744  0.92432141  2.66718864 -6.96903086
#   1.25003374 -6.2420783  -0.01316099 -5.32654428]
# relevance from y_target -0.647742
# relevance from y_pred 2.66719
# ======
# ------
# target 8 -> pred  5
# y_pred [-1.17237937 -3.50208473 -3.19993329 -1.83902657 -2.80682158  2.2668035
#  -0.51616347  0.53054827 -1.37505043  1.00015676]
# relevance from y_target -1.37505
# relevance from y_pred 2.2668
# ======
# ------
# target 4 -> pred  6
# y_pred [ 1.79779267 -5.62038326  2.34105444  0.51060504 -0.34260696 -6.81676006
#   4.24876833 -7.42650461 -2.25281549 -7.37937164]
# relevance from y_target -0.342607
# relevance from y_pred 4.24877
# ======
# ------
# target 8 -> pred  3
# y_pred [  0.71560115  -1.51814735   1.62654901   5.06546879   1.76631284
#  -10.02715206   1.71961844  -7.34827328  -2.6669929   -9.0468998 ]
# relevance from y_target -2.66699
# relevance from y_pred 5.06547
# ======
# ------
# target 3 -> pred  2
# y_pred [  0.7405988   -4.10434818   7.58819389  -1.33855677   3.80776787
#  -14.07210636   2.69686937 -18.05435371  -2.98061156 -13.51201439]
# relevance from y_target -1.33856
# relevance from y_pred 7.58819
# ======
# ------
# target 0 -> pred  8
# y_pred [ -6.89724207e-01  -5.21167469e+00  -1.97333956e+00  -3.61533451e+00
#   -2.62245512e+00  -3.48234892e+00  -1.67780230e-03  -2.62247300e+00
#    3.64047551e+00  -4.48756838e+00]
# relevance from y_target -0.689724
# relevance from y_pred 3.64048
# ======
# relevance >= 0 : 0.996300

# %%
count_positive_relevances('../experiment-results/aws-training/convdeep_4l_artificial_output-fashion-mnist-seq-4---2018-01-25--12-21-03')
# Out:
# (<tf.Tensor 'strided_slice_4:0' shape=() dtype=int32>, 1)
# (?, 11)
# Positive relevance for model convdeep_4l_artificial_output-fashion-mnist-seq-4---2018-01-25--12-21-03
# there are 5 negative relevance (y_pred_y_target)
# and there are 0 negative relevance (max y_pred)
# ------
# target 8 -> pred  4
# y_pred [ 0.8179099  -0.53656679  3.40003252  2.31919956  5.54576206 -4.04249763
#   3.64640999 -4.35346842 -0.07009064 -4.13165283]
# relevance from y_target -0.0700906
# relevance from y_pred 5.54576
# ======
# ------
# target 0 -> pred  5
# y_pred [-0.49959904 -3.43107271  0.11246274 -3.23811197 -1.23179185  4.35488939
#  -1.08374286  1.8751955   0.72327441  1.43255877]
# relevance from y_target -0.499599
# relevance from y_pred 4.35489
# ======
# ------
# target 1 -> pred  8
# y_pred [ 3.73920131 -0.35564005  3.21159673 -1.04377007  1.07000434 -3.40711641
#   5.88399601 -5.30071402  6.66980171 -2.50602317]
# relevance from y_target -0.35564
# relevance from y_pred 6.6698
# ======
# ------
# target 0 -> pred  4
# y_pred [ -0.07073559  -0.73669487   7.5705719    2.62568307  13.76064301
#   -7.92217731   6.05323124  -7.89524651   2.08444881  -5.99862957]
# relevance from y_target -0.0707356
# relevance from y_pred 13.7606
# ======
# ------
# target 1 -> pred  4
# y_pred [ 1.59991038 -0.64725518  4.05729532  3.46425557  4.06188297 -3.92626023
#   3.2360096  -3.71839738  0.6155951  -4.02196598]
# relevance from y_target -0.647255
# relevance from y_pred 4.06188
# ======
# relevance >= 0 : 0.999500

# %%
count_positive_relevances('../experiment-results/aws-training/convdeep_4l_artificial_output-fashion-mnist-seq-1---2018-01-27--13-37-13')
# Out:
# (<tf.Tensor 'strided_slice_1:0' shape=() dtype=int32>, 1)
# (?, 11)
# Positive relevance for model convdeep_4l_artificial_output-fashion-mnist-seq-1---2018-01-27--13-37-13
# there are 0 negative relevance (y_pred_y_target)
# and there are 0 negative relevance (max y_pred)
# relevance >= 0 : 1.000000
