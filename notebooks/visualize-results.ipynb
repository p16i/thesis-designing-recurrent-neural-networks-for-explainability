# %%
import logging
import matplotlib.pyplot as plt
from utils import logging as lg

lg.set_logging(logging.INFO)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from utils import experiment_artifact

pd.set_option('display.max_colwidth', 70)

# %%
def get_results(name):
    return experiment_artifact.get_results(name)\
    .sort_values(by='accuracy', ascending=False)

# %%
df = get_results('../experiment-results/sprint-10-ufi')
    
df
# Out:
#     accuracy                                        architecture  \
# 11  0.300826   in1:2000|hidden:1000|out1:800|out2:605--recur:256
# 9   0.276033   in1:1300|hidden:1000|out1:800|out2:605--recur:256
# 10  0.266116   in1:2000|hidden:1000|out1:800|out2:605--recur:256
# 7   0.233058  in1:1500|hidden:1500|out1:1000|out2:605--recur:256
# 8   0.226446   in1:1300|hidden:1000|out1:800|out2:605--recur:256
# 5   0.132231  in1:1500|hidden:1500|out1:1000|out2:605--recur:256
# 4   0.092562  in1:1500|hidden:1500|out1:1000|out2:605--recur:256
# 3   0.052893  in1:1500|hidden:1500|out1:1000|out2:605--recur:256
# 12  0.008264   in1:2000|hidden:1000|out1:800|out2:605--recur:256
# 6   0.004959  in1:1500|hidden:1500|out1:1000|out2:605--recur:256
# 1   0.003306      in1:512|hidden:128|out1:64|out2:605--recur:256
# 2   0.001653    in1:1024|hidden:512|out1:256|out2:605--recur:256
# 13  0.001653      in1:512|hidden:128|out1:64|out2:605--recur:256
# 0   0.000000      in1:512|hidden:128|out1:64|out2:605--recur:256
#
#    architecture_name  batch  column_at_a_time      dataset  dims  epoch  \
# 11        s3_network     50                64  ufi-cropped    64    200
# 9         s3_network    100                64  ufi-cropped    64    200
# 10        s3_network    100                64  ufi-cropped    64    200
# 7         s3_network    100                64  ufi-cropped    64    100
# 8         s3_network    100                64  ufi-cropped    64    100
# 5         s3_network    100                64  ufi-cropped    64    100
# 4         s3_network    100                64  ufi-cropped    64    100
# 3         s3_network    100                64  ufi-cropped    64     50
# 12        s3_network     50                64  ufi-cropped    64    200
# 6         s3_network    100                64  ufi-cropped    64    100
# 1         s3_network    100                64  ufi-cropped    64     50
# 2         s3_network    100                64  ufi-cropped    64     50
# 13        s3_network    100                16  ufi-cropped    64      5
# 0         s3_network    100                64  ufi-cropped    64      5
#
#                                         experiment_name  keep_prob      lr  \
# 11  s3_network-ufi-cropped-seq-1---2018-01-13--23-20-34        0.7  0.0005
# 9   s3_network-ufi-cropped-seq-1---2018-01-13--15-22-55        0.7  0.0010
# 10  s3_network-ufi-cropped-seq-1---2018-01-13--16-32-58        0.7  0.0001
# 7   s3_network-ufi-cropped-seq-1---2018-01-13--13-19-31        1.0  0.0010
# 8   s3_network-ufi-cropped-seq-1---2018-01-13--14-26-48        0.7  0.0010
# 5   s3_network-ufi-cropped-seq-1---2018-01-13--11-32-39        0.7  0.0010
# 4   s3_network-ufi-cropped-seq-1---2018-01-13--01-23-55        0.7  0.0001
# 3   s3_network-ufi-cropped-seq-1---2018-01-13--01-08-06        0.7  0.0010
# 12  s3_network-ufi-cropped-seq-1---2018-01-14--17-03-34        0.7  0.0008
# 6   s3_network-ufi-cropped-seq-1---2018-01-13--12-49-26        0.5  0.0010
# 1   s3_network-ufi-cropped-seq-1---2018-01-13--00-40-20        0.5  0.0001
# 2   s3_network-ufi-cropped-seq-1---2018-01-13--00-44-44        0.5  0.0001
# 13  s3_network-ufi-cropped-seq-4---2018-01-13--00-39-51        0.5  0.0001
# 0   s3_network-ufi-cropped-seq-1---2018-01-13--00-39-23        0.5  0.0001
#
#     max_seq_length      optimizer  regularizer  seq_length  val_accuracy
# 11              64  AdamOptimizer          0.0           1      0.300826
# 9               64  AdamOptimizer          0.0           1      0.276033
# 10              64  AdamOptimizer          0.0           1      0.266116
# 7               64  AdamOptimizer          0.0           1      0.233058
# 8               64  AdamOptimizer          0.0           1      0.226446
# 5               64  AdamOptimizer          0.0           1      0.132231
# 4               64  AdamOptimizer          0.0           1      0.092562
# 3               64  AdamOptimizer          0.0           1      0.052893
# 12              64  AdamOptimizer          0.0           1      0.008264
# 6               64  AdamOptimizer          0.0           1      0.004959
# 1               64  AdamOptimizer          0.0           1      0.003306
# 2               64  AdamOptimizer          0.0           1      0.001653
# 13              64  AdamOptimizer          0.0           4      0.001653
# 0               64  AdamOptimizer          0.0           1      0.000000
