# %%
import logging

from utils import logging as lg

lg.set_logging(logging.INFO)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from utils import experiment_artifact

# %%
import imp
imp.reload(experiment_artifact)
df_results = experiment_artifact.get_results('../experiment-results/sprint-2-network').sort_values(by='accuracy', ascending=False)

df_results
# Out:
#     accuracy                  architecture architecture_name  batch  \
# 22    0.9781  hidden:100|out:10--recur:100        s2_network    200
# 21    0.9735  hidden:100|out:10--recur:100        s2_network    200
# 5     0.9733  hidden:100|out:10--recur:100              type    200
# 7     0.9715  hidden:100|out:10--recur:100              type    200
# 18    0.8804  hidden:100|out:10--recur:100        s2_network    200
# 4     0.8802   hidden:100|out:10--recur:50              type    200
# 6     0.8780  hidden:100|out:10--recur:100              type    200
# 1     0.8732    hidden:100|out:10--recur:7        s2_network    100
# 26    0.8721   hidden:100|out:10--recur:50        s2_network    200
# 23    0.8676  hidden:100|out:10--recur:100        s2_network    200
# 25    0.8642   hidden:100|out:10--recur:50        s2_network    200
# 20    0.7829  hidden:200|out:10--recur:100        s2_network    200
# 3     0.7802    hidden:100|out:10--recur:7        s2_network    200
# 27    0.7784   hidden:100|out:10--recur:50        s2_network    200
# 8     0.7764  hidden:100|out:10--recur:100              type    200
# 9     0.7540  hidden:100|out:10--recur:100        s2_network    200
# 10    0.6885    hidden:100|out:10--recur:7        s2_network    200
# 19    0.6693  hidden:100|out:10--recur:200        s2_network    200
# 31    0.6604   hidden:100|out:10--recur:10        s2_network    100
# 11    0.6411   hidden:100|out:10--recur:14        s2_network    200
# 36    0.5984   hidden:100|out:10--recur:10        s2_network    500
# 37    0.5843   hidden:100|out:10--recur:10        s2_network     50
# 2     0.5841    hidden:150|out:10--recur:7        s2_network    100
# 0     0.5819     hidden:60|out:10--recur:7        s2_network    100
# 35    0.5716   hidden:100|out:10--recur:10        s2_network    200
# 24    0.5706   hidden:100|out:10--recur:50        s2_network    200
# 13    0.5337    hidden:100|out:10--recur:7        s2_network    200
# 28    0.4846   hidden:100|out:10--recur:50        s2_network    200
# 17    0.4801   hidden:100|out:10--recur:50        s2_network    200
# 34    0.4738   hidden:100|out:10--recur:10        s2_network    200
# 38    0.4697   hidden:100|out:10--recur:10        s2_network     50
# 12    0.4381    hidden:100|out:10--recur:7        s2_network    100
# 33    0.4018   hidden:100|out:10--recur:10        s2_network    100
# 32    0.3899   hidden:100|out:10--recur:10        s2_network    100
# 15    0.3889    hidden:100|out:10--recur:7        s2_network    200
# 14    0.3749    hidden:100|out:10--recur:7        s2_network    200
# 30    0.2944   hidden:100|out:10--recur:50        s2_network    100
# 16    0.2934    hidden:100|out:10--recur:7        s2_network    200
# 29    0.0980   hidden:100|out:10--recur:50        s2_network    200
#
#     column_at_a_time  dims  epoch        experiment_name  keep_prob      lr  \
# 22                 4  28.0     50  rnn-2017-10-19--12-43        0.8  0.0025
# 21                 4  28.0     50  rnn-2017-10-19--12-41        1.0  0.0025
# 5                  4  28.0     50  rnn-2017-10-17--01-27        NaN  0.0050
# 7                  4  28.0     50  rnn-2017-10-17--01-48        NaN  0.0050
# 18                 4  28.0     50  rnn-2017-10-19--12-31        1.0  0.0050
# 4                  4  28.0     50  rnn-2017-10-17--01-05        NaN  0.0050
# 6                  4  28.0     50  rnn-2017-10-17--01-44        NaN  0.0050
# 1                  4   NaN     50  rnn-2017-10-16--09-57        NaN  0.0050
# 26                 4  28.0     50  rnn-2017-10-19--13-01        0.8  0.0050
# 23                 4  28.0     50  rnn-2017-10-19--12-47        0.8  0.0025
# 25                 4  28.0     50  rnn-2017-10-19--12-53        0.8  0.0025
# 20                 4  28.0     50  rnn-2017-10-19--12-38        1.0  0.0025
# 3                  4   NaN     50  rnn-2017-10-16--10-17        NaN  0.0050
# 27                 4  28.0     50  rnn-2017-10-19--13-08        1.0  0.0050
# 8                  4  28.0     50  rnn-2017-10-17--23-06        NaN  0.0050
# 9                  4  28.0     50  rnn-2017-10-18--00-12        NaN  0.0050
# 10                 4  28.0     50  rnn-2017-10-19--12-09        0.5  0.0050
# 19                 4  28.0     50  rnn-2017-10-19--12-33        1.0  0.0050
# 31                 4  28.0     50  rnn-2017-10-19--13-25        1.0  0.0025
# 11                 4  28.0     50  rnn-2017-10-19--12-11        0.5  0.0050
# 36                 4  28.0     50  rnn-2017-10-19--13-36        1.0  0.0050
# 37                 4  28.0     50  rnn-2017-10-19--13-38        1.0  0.0050
# 2                  4   NaN     50  rnn-2017-10-16--10-10        NaN  0.0050
# 0                  4   NaN     50  rnn-2017-10-16--09-48        NaN  0.0050
# 35                 4  28.0     50  rnn-2017-10-19--13-35        1.0  0.0050
# 24                 4  28.0     50  rnn-2017-10-19--12-49        0.8  0.0025
# 13                 4  28.0     50  rnn-2017-10-19--12-21        0.5  0.0050
# 28                 4  28.0     50  rnn-2017-10-19--13-18        1.0  0.0025
# 17                 4  28.0     50  rnn-2017-10-19--12-28        1.0  0.0050
# 34                 4  28.0     50  rnn-2017-10-19--13-33        1.0  0.0025
# 38                 4  28.0     50  rnn-2017-10-19--13-46        1.0  0.0025
# 12                 4  28.0     50  rnn-2017-10-19--12-19        0.5  0.0050
# 33                 4  28.0     50  rnn-2017-10-19--13-30        1.0  0.0025
# 32                 4  28.0     50  rnn-2017-10-19--13-28        1.0  0.0010
# 15                 4  28.0     50  rnn-2017-10-19--12-25        1.0  0.0050
# 14                 4  28.0     50  rnn-2017-10-19--12-23        0.8  0.0050
# 30                 4  28.0     50  rnn-2017-10-19--13-22        1.0  0.0025
# 16                 4  28.0     50  rnn-2017-10-19--12-27        1.0  0.0050
# 29                 4  28.0     50  rnn-2017-10-19--13-20        1.0  0.0080
#
#     max_seq_length  seq_length
# 22            28.0           7
# 21            28.0           7
# 5             28.0           7
# 7             28.0           7
# 18            28.0           7
# 4             28.0           7
# 6             28.0           7
# 1              NaN           7
# 26            28.0           7
# 23            28.0           7
# 25            28.0           7
# 20            28.0           7
# 3              NaN           7
# 27            28.0           7
# 8             28.0           7
# 9             28.0           7
# 10            28.0           7
# 19            28.0           7
# 31            28.0           7
# 11            28.0           7
# 36            28.0           7
# 37            28.0           7
# 2              NaN           7
# 0              NaN           7
# 35            28.0           7
# 24            28.0           7
# 13            28.0           7
# 28            28.0           7
# 17            28.0           7
# 34            28.0           7
# 38            28.0           7
# 12            28.0           7
# 33            28.0           7
# 32            28.0           7
# 15            28.0           7
# 14            28.0           7
# 30            28.0           7
# 16            28.0           7
# 29            28.0           7

# %%
df_results_s3 = experiment_artifact.get_results('../experiment-results/sprint-3-network').sort_values(by='accuracy', ascending=False)
df_results_s3
# Out:
#    accuracy                                   architecture architecture_name  \
# 1    0.9753    in1:100|hidden:60|out1:30|out2:10--recur:30        s3_network
# 7    0.9674   in1:100|hidden:60|out1:30|out2:10--recur:100        s3_network
# 8    0.9668  in1:100|hidden:150|out1:75|out2:10--recur:100        s3_network
# 0    0.9592     in1:100|hidden:60|out1:30|out2:10--recur:7        s3_network
# 2    0.9526    in1:100|hidden:60|out1:30|out2:10--recur:30        s3_network
# 6    0.8872   in1:100|hidden:60|out1:30|out2:10--recur:100        s3_network
# 5    0.8050    in1:100|hidden:60|out1:30|out2:10--recur:30        s3_network
# 3    0.0980    in1:100|hidden:60|out1:30|out2:10--recur:30        s3_network
# 4    0.0980    in1:100|hidden:60|out1:30|out2:10--recur:30        s3_network
#
#    batch  column_at_a_time  dims  epoch        experiment_name  keep_prob  \
# 1    200                 4    28     50  rnn-2017-10-18--21-54        NaN
# 7    200                 4    28     50  rnn-2017-10-19--14-21        0.8
# 8    200                 4    28     50  rnn-2017-10-19--14-24        0.8
# 0    200                 4    28     50  rnn-2017-10-18--01-12        NaN
# 2    200                 2    28     50  rnn-2017-10-18--21-59        NaN
# 6    200                 4    28     50  rnn-2017-10-19--14-18        0.5
# 5    200                 1    28     30  rnn-2017-10-18--22-25        NaN
# 3    200                 1    28     50  rnn-2017-10-18--22-05        NaN
# 4    200                 1    28     20  rnn-2017-10-18--22-14        NaN
#
#       lr  max_seq_length  seq_length
# 1  0.005              28           7
# 7  0.005              28           7
# 8  0.005              28           7
# 0  0.005              28           7
# 2  0.005              28          14
# 6  0.005              28           7
# 5  0.005              28          28
# 3  0.005              28          28
# 4  0.005              28          28

# %%
df_results_s4 = experiment_artifact.get_results('../experiment-results/sprint-4').sort_values(by='accuracy', ascending=False)
df_results_s4[df_results_s4.column_at_a_time == 4][df_results_s4.architecture_name == 's2_network']
# Out:
# /Users/heytitle/projects/heatmapping-tutorial/venv/lib/python3.5/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#     accuracy                  architecture architecture_name  batch  \
# 50    0.8738   hidden:100|out:10--recur:10        s2_network    100
# 44    0.8720  hidden:100|out:10--recur:100        s2_network    100
# 45    0.7952  hidden:100|out:10--recur:100        s2_network    100
# 49    0.7669   hidden:100|out:10--recur:10        s2_network    100
# 75    0.7609  hidden:100|out:10--recur:100        s2_network    100
# 43    0.6897  hidden:100|out:10--recur:100        s2_network    100
# 42    0.6667   hidden:100|out:10--recur:50        s2_network    100
# 48    0.6012   hidden:100|out:10--recur:50        s2_network    100
# 46    0.5950  hidden:100|out:10--recur:100        s2_network    100
# 47    0.5043   hidden:100|out:10--recur:50        s2_network    100
#
#     column_at_a_time  dims  epoch        experiment_name  keep_prob      lr  \
# 50                 4    28     50  rnn-2017-10-19--19-31        1.0  0.0025
# 44                 4    28     50  rnn-2017-10-19--19-16        0.8  0.0025
# 45                 4    28     50  rnn-2017-10-19--19-20        0.8  0.0025
# 49                 4    28     50  rnn-2017-10-19--19-29        0.8  0.0025
# 75                 4    28     50  rnn-2017-10-19--22-27        0.8  0.0025
# 43                 4    28     50  rnn-2017-10-19--19-13        0.8  0.0025
# 42                 4    28     50  rnn-2017-10-19--18-58        0.8  0.0025
# 48                 4    28     50  rnn-2017-10-19--19-27        1.0  0.0025
# 46                 4    28     50  rnn-2017-10-19--19-22        1.0  0.0025
# 47                 4    28     50  rnn-2017-10-19--19-25        0.8  0.0025
#
#     max_seq_length  seq_length
# 50              28           7
# 44              28           7
# 45              28           7
# 49              28           7
# 75              28           7
# 43              28           7
# 42              28           7
# 48              28           7
# 46              28           7
# 47              28           7

# %%
df_results_s4[df_results_s4.column_at_a_time == 2][df_results_s4.architecture_name == 's2_network']
# Out:
# /Users/heytitle/projects/heatmapping-tutorial/venv/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#     accuracy                 architecture architecture_name  batch  \
# 57    0.7007  hidden:50|out:10--recur:100        s2_network    100
# 59    0.6146   hidden:50|out:10--recur:50        s2_network    100
# 58    0.5771  hidden:50|out:10--recur:100        s2_network    100
# 60    0.3834   hidden:50|out:10--recur:50        s2_network    100
# 62    0.2934   hidden:50|out:10--recur:10        s2_network    100
# 61    0.2810   hidden:50|out:10--recur:10        s2_network    100
#
#     column_at_a_time  dims  epoch        experiment_name  keep_prob      lr  \
# 57                 2    28     50  rnn-2017-10-19--20-12        0.8  0.0025
# 59                 2    28     50  rnn-2017-10-19--20-20        0.8  0.0025
# 58                 2    28     50  rnn-2017-10-19--20-16        1.0  0.0025
# 60                 2    28     50  rnn-2017-10-19--20-22        1.0  0.0025
# 62                 2    28     50  rnn-2017-10-19--20-27        1.0  0.0025
# 61                 2    28     50  rnn-2017-10-19--20-25        0.8  0.0025
#
#     max_seq_length  seq_length
# 57              28          14
# 59              28          14
# 58              28          14
# 60              28          14
# 62              28          14
# 61              28          14

# %%
df_results_s4[df_results_s4.column_at_a_time == 1][df_results_s4.architecture_name == 's2_network']
# Out:
# /Users/heytitle/projects/heatmapping-tutorial/venv/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#     accuracy                  architecture architecture_name  batch  \
# 78    0.5884   hidden:150|out:10--recur:50        s2_network    100
# 77    0.4701  hidden:150|out:10--recur:100        s2_network    100
# 79    0.3557   hidden:150|out:10--recur:10        s2_network    100
# 74    0.2412    hidden:50|out:10--recur:10        s2_network    100
# 76    0.0980  hidden:150|out:10--recur:100        s2_network    100
# 72    0.0980    hidden:50|out:10--recur:50        s2_network    100
# 73    0.0980    hidden:50|out:10--recur:10        s2_network    100
# 71    0.0980    hidden:50|out:10--recur:50        s2_network    100
# 70    0.0980   hidden:50|out:10--recur:100        s2_network    100
# 69    0.0980   hidden:50|out:10--recur:100        s2_network    100
#
#     column_at_a_time  dims  epoch        experiment_name  keep_prob      lr  \
# 78                 1    28     50  rnn-2017-10-19--23-02        1.0  0.0010
# 77                 1    28     50  rnn-2017-10-19--22-51        1.0  0.0010
# 79                 1    28     50  rnn-2017-10-19--23-10        1.0  0.0010
# 74                 1    28     50  rnn-2017-10-19--22-19        1.0  0.0025
# 76                 1    28     50  rnn-2017-10-19--22-35        0.8  0.0025
# 72                 1    28     50  rnn-2017-10-19--22-10        1.0  0.0025
# 73                 1    28     50  rnn-2017-10-19--22-15        0.8  0.0025
# 71                 1    28     50  rnn-2017-10-19--22-05        0.8  0.0025
# 70                 1    28     50  rnn-2017-10-19--21-59        1.0  0.0025
# 69                 1    28     50  rnn-2017-10-19--21-52        0.8  0.0025
#
#     max_seq_length  seq_length
# 78              28          28
# 77              28          28
# 79              28          28
# 74              28          28
# 76              28          28
# 72              28          28
# 73              28          28
# 71              28          28
# 70              28          28
# 69              28          28
