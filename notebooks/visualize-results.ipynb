# %%
import logging

from utils import logging as lg

lg.set_logging(logging.INFO)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from utils import experiment_artifact

pd.set_option('display.max_colwidth', 70)

# %%
def get_results(name):
    return experiment_artifact.get_results(name)\
    .sort_values(by='accuracy', ascending=False)

# %%
import imp
imp.reload(experiment_artifact)
df_results = experiment_artifact.get_results('../experiment-results/sprint-5').sort_values(by='accuracy', ascending=False)

df_results[df_results.architecture_name =='s2_network']
# Out:
#     accuracy                   architecture architecture_name  batch  \
# 96    0.9816  hidden:1000|out:10--recur:100        s2_network    100
# 91    0.9813  hidden:1000|out:10--recur:200        s2_network    100
# 74    0.9808    hidden:400|out:10--recur:50        s2_network    100
# 97    0.9765  hidden:1000|out:10--recur:200        s2_network    100
# 83    0.9764    hidden:800|out:10--recur:50        s2_network    100
# 73    0.9762   hidden:400|out:10--recur:200        s2_network    100
# 0     0.9760    hidden:100|out:10--recur:50        s2_network    100
# 80    0.9759    hidden:800|out:10--recur:50        s2_network    100
# 82    0.9719   hidden:800|out:10--recur:200        s2_network    100
# 4     0.8838   hidden:200|out:10--recur:100        s2_network    100
# 1     0.8816   hidden:100|out:10--recur:100        s2_network    100
# 75    0.8800   hidden:400|out:10--recur:100        s2_network    100
# 71    0.7970    hidden:400|out:10--recur:50        s2_network    100
# ...

# %%
df_results_s3 = experiment_artifact.get_results('../experiment-results/sprint-3-network').sort_values(by='accuracy', ascending=False)
df_results_s3
# Out:
#    accuracy                                   architecture architecture_name  \
# 1    0.9753    in1:100|hidden:60|out1:30|out2:10--recur:30        s3_network
# 7    0.9674   in1:100|hidden:60|out1:30|out2:10--recur:100        s3_network
# 8    0.9668  in1:100|hidden:150|out1:75|out2:10--recur:100        s3_network
# 0    0.9592     in1:100|hidden:60|out1:30|out2:10--recur:7        s3_network
# 2    0.9526    in1:100|hidden:60|out1:30|out2:10--recur:30        s3_network
# 6    0.8872   in1:100|hidden:60|out1:30|out2:10--recur:100        s3_network
# 5    0.8050    in1:100|hidden:60|out1:30|out2:10--recur:30        s3_network
# 3    0.0980    in1:100|hidden:60|out1:30|out2:10--recur:30        s3_network
# 4    0.0980    in1:100|hidden:60|out1:30|out2:10--recur:30        s3_network
#
#    batch  column_at_a_time  dims  epoch        experiment_name  keep_prob  \
# 1    200                 4    28     50  rnn-2017-10-18--21-54        NaN
# ...

# %%
df_results_s4 = experiment_artifact.get_results('../experiment-results/sprint-4').sort_values(by='accuracy', ascending=False)
df_results_s4[df_results_s4.column_at_a_time == 4][df_results_s4.architecture_name == 's3_network']
# Out:
# /Users/heytitle/projects/heatmapping-tutorial/venv/lib/python3.5/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#     accuracy                                   architecture architecture_name  \
# 8     0.9796   in1:100|hidden:100|out1:75|out2:10--recur:50        s3_network
# 40    0.9763   in1:100|hidden:100|out1:75|out2:10--recur:10        s3_network
# 39    0.9762   in1:100|hidden:100|out1:75|out2:10--recur:50        s3_network
# 41    0.9760  in1:100|hidden:100|out1:75|out2:10--recur:100        s3_network
# 10    0.9749   in1:100|hidden:100|out1:75|out2:10--recur:50        s3_network
# 16    0.9733   in1:100|hidden:100|out1:75|out2:10--recur:10        s3_network
# 4     0.9731  in1:100|hidden:100|out1:75|out2:10--recur:100        s3_network
# 14    0.9730   in1:100|hidden:100|out1:75|out2:10--recur:10        s3_network
# 11    0.9721   in1:100|hidden:100|out1:75|out2:10--recur:50        s3_network
# ...

# %%
df_results_s4[df_results_s4.column_at_a_time == 2][df_results_s4.architecture_name == 's2_network']
# Out:
# /Users/heytitle/projects/heatmapping-tutorial/venv/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#     accuracy                 architecture architecture_name  batch  \
# 57    0.7007  hidden:50|out:10--recur:100        s2_network    100
# 59    0.6146   hidden:50|out:10--recur:50        s2_network    100
# 58    0.5771  hidden:50|out:10--recur:100        s2_network    100
# 60    0.3834   hidden:50|out:10--recur:50        s2_network    100
# 62    0.2934   hidden:50|out:10--recur:10        s2_network    100
# 61    0.2810   hidden:50|out:10--recur:10        s2_network    100
#
#     column_at_a_time  dims  epoch        experiment_name  keep_prob      lr  \
# 57                 2    28     50  rnn-2017-10-19--20-12        0.8  0.0025
# 59                 2    28     50  rnn-2017-10-19--20-20        0.8  0.0025
# ...

# %%
df_results_s4[df_results_s4.column_at_a_time == 1][df_results_s4.architecture_name == 's2_network']
# Out:
# /Users/heytitle/projects/heatmapping-tutorial/venv/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#     accuracy                  architecture architecture_name  batch  \
# 78    0.5884   hidden:150|out:10--recur:50        s2_network    100
# 77    0.4701  hidden:150|out:10--recur:100        s2_network    100
# 79    0.3557   hidden:150|out:10--recur:10        s2_network    100
# 74    0.2412    hidden:50|out:10--recur:10        s2_network    100
# 76    0.0980  hidden:150|out:10--recur:100        s2_network    100
# 72    0.0980    hidden:50|out:10--recur:50        s2_network    100
# 73    0.0980    hidden:50|out:10--recur:10        s2_network    100
# 71    0.0980    hidden:50|out:10--recur:50        s2_network    100
# 70    0.0980   hidden:50|out:10--recur:100        s2_network    100
# ...

# %% [markdown]
# # Sprint 5th

# %%
df_results_s5 = experiment_artifact.get_results('../experiment-results/sprint-5-seq-length-1').sort_values(by='accuracy', ascending=False)
df_results_s5[ (df_results_s5.architecture_name == 's2_network') & (df_results_s5.optimizer == 'AdamOptimizer')]
# Out:
#     accuracy                  architecture architecture_name  batch  \
# 56    0.9779  hidden:600|out:10--recur:100        s2_network     50
# 62    0.9777  hidden:600|out:10--recur:100        s2_network     50
# 48    0.9723  hidden:300|out:10--recur:100        s2_network     50
# 61    0.8833  hidden:600|out:10--recur:100        s2_network     50
# 52    0.8801  hidden:300|out:10--recur:100        s2_network     50
# 51    0.8662  hidden:300|out:10--recur:100        s2_network     50
# 58    0.8641  hidden:600|out:10--recur:100        s2_network     50
# 54    0.7855  hidden:300|out:10--recur:100        s2_network     50
# 60    0.7835  hidden:600|out:10--recur:100        s2_network     50
# 49    0.7787  hidden:300|out:10--recur:100        s2_network     50
# 53    0.7701  hidden:300|out:10--recur:100        s2_network     50
# 47    0.7669  hidden:500|out:10--recur:100        s2_network     50
# 57    0.6827  hidden:600|out:10--recur:100        s2_network     50
# ...

# %%
df_results_s5[df_results_s5.architecture_name == 's3_network'].sort_values('experiment_name', ascending=False)
# Out:
#     accuracy                                   architecture architecture_name  \
# 46    0.6342   in1:300|hidden:100|out1:50|out2:10--recur:50        s3_network
# 45    0.3947   in1:300|hidden:100|out1:50|out2:10--recur:50        s3_network
# 44    0.2810   in1:300|hidden:100|out1:50|out2:10--recur:50        s3_network
# 43    0.5339   in1:300|hidden:100|out1:50|out2:10--recur:50        s3_network
# 42    0.7832   in1:300|hidden:100|out1:50|out2:10--recur:50        s3_network
# 41    0.2113   in1:300|hidden:100|out1:50|out2:10--recur:50        s3_network
# 40    0.9773   in1:300|hidden:100|out1:50|out2:10--recur:50        s3_network
# 39    0.9120   in1:300|hidden:100|out1:50|out2:10--recur:50        s3_network
# 38    0.5847   in1:300|hidden:100|out1:50|out2:10--recur:50        s3_network
# 37    0.9714   in1:300|hidden:100|out1:50|out2:10--recur:50        s3_network
# 36    0.7061   in1:300|hidden:100|out1:50|out2:10--recur:50        s3_network
# ...

# %%
experiment_artifact.get_results('../experiment-results/sprint-5-seq-2-recur-effect').sort_values(by='experiment_name', ascending=False)
# Out:
#    accuracy                                 architecture architecture_name  \
# 3    0.9594  in1:100|hidden:75|out1:25|out2:10--recur:30        s3_network
# 2    0.9585  in1:100|hidden:75|out1:25|out2:10--recur:10        s3_network
# 1    0.9502   in1:100|hidden:75|out1:25|out2:10--recur:5        s3_network
# 0    0.9255   in1:100|hidden:75|out1:25|out2:10--recur:1        s3_network
#
#    batch  column_at_a_time  dims  epoch        experiment_name  keep_prob  \
# 3     50                14    28    200  rnn-2017-11-02--00-49        0.2
# 2     50                14    28    200  rnn-2017-11-02--00-42        0.2
# 1     50                14    28    200  rnn-2017-11-02--00-35        0.2
# 0     50                14    28    200  rnn-2017-11-02--00-28        0.2
#
#         lr  max_seq_length      optimizer  seq_length
# 3  0.00005              28  AdamOptimizer           2
# 2  0.00005              28  AdamOptimizer           2
# 1  0.00005              28  AdamOptimizer           2
# ...

# %%
experiment_artifact.get_results('../experiment-results/sprint-5-seq-4').sort_values(by='accuracy', ascending=False)
# Out:
#    accuracy                                 architecture architecture_name  \
# 7    0.9381  in1:200|hidden:30|out1:20|out2:10--recur:20        s3_network
# 8    0.9343  in1:200|hidden:30|out1:20|out2:10--recur:50        s3_network
# 4    0.8916  in1:100|hidden:30|out1:20|out2:10--recur:50        s3_network
# 3    0.8795  in1:100|hidden:30|out1:20|out2:10--recur:20        s3_network
# 6    0.7012  in1:200|hidden:30|out1:20|out2:10--recur:50        s3_network
# 0    0.6799  in1:200|hidden:30|out1:20|out2:10--recur:50        s3_network
# 5    0.6688  in1:200|hidden:30|out1:20|out2:10--recur:20        s3_network
# 1    0.6538  in1:100|hidden:30|out1:20|out2:10--recur:20        s3_network
# 2    0.4752  in1:100|hidden:30|out1:20|out2:10--recur:50        s3_network
#
#    batch  column_at_a_time  dims  epoch        experiment_name  keep_prob  \
# 7     50                 7    28    500  rnn-2017-11-03--03-48       0.05
# ...

# %%
experiment_artifact.get_results('../experiment-results/sprint-6-bayesian').sort_values(by='val_accuracy', ascending=False)
# Out:
#     accuracy                 architecture architecture_name  batch  \
# 14    0.4740  hidden:200|out:10--recur:20        s2_network     50
# 10    0.4407  hidden:200|out:10--recur:20        s2_network     50
# 3     0.4224  hidden:200|out:10--recur:20        s2_network     50
# 8     0.3920  hidden:200|out:10--recur:20        s2_network     50
# 5     0.3845  hidden:200|out:10--recur:20        s2_network     50
# 18    0.3554  hidden:200|out:10--recur:20        s2_network     50
# 17    0.3521  hidden:200|out:10--recur:20        s2_network     50
# 12    0.3451  hidden:200|out:10--recur:20        s2_network     50
# 16    0.2541  hidden:200|out:10--recur:20        s2_network     50
# 7     0.2082  hidden:200|out:10--recur:20        s2_network     50
# 15    0.0980  hidden:200|out:10--recur:20        s2_network     50
# 13    0.0980  hidden:200|out:10--recur:20        s2_network     50
# 0     0.0980  hidden:200|out:10--recur:20        s2_network     50
# ...

# %%
experiment_artifact.get_results('../experiment-results/sprint-6').sort_values(by='val_accuracy', ascending=False)
# Out:
#     accuracy                                    architecture  \
# 49    0.9840    in1:800|hidden:200|out1:70|out2:10--recur:50
# 18    0.9831                   hidden:1000|out:10--recur:200
# 34    0.9827    in1:800|hidden:200|out1:70|out2:10--recur:50
# 47    0.9815    in1:800|hidden:100|out1:70|out2:10--recur:50
# 45    0.9839    in1:800|hidden:200|out1:70|out2:10--recur:50
# 46    0.9823    in1:400|hidden:100|out1:70|out2:10--recur:50
# 48    0.9802    in1:800|hidden:200|out1:70|out2:10--recur:50
# 7     0.9806                     hidden:800|out:10--recur:50
# 35    0.9794    in1:200|hidden:200|out1:70|out2:10--recur:50
# 2     0.9774                    hidden:800|out:10--recur:200
# 39    0.9818  in1:200|hidden:200|out1:100|out2:10--recur:100
# 20    0.9803                    hidden:800|out:10--recur:200
# 41    0.9762  in1:200|hidden:200|out1:100|out2:10--recur:100
# 1     0.9776                    hidden:800|out:10--recur:200
# ...

# %%
df = experiment_artifact.get_results('../experiment-results/sprint-6-improve-dropout-ly')\
    .sort_values(by='val_accuracy', ascending=False)
    
df[ df.architecture_name =='s3_network']
# Out:
#    accuracy                                    architecture architecture_name  \
# 6    0.9844  in1:1000|hidden:300|out1:100|out2:10--recur:50        s3_network
# 3    0.9859    in1:800|hidden:200|out1:70|out2:10--recur:50        s3_network
# 5    0.9846  in1:1000|hidden:300|out1:100|out2:10--recur:50        s3_network
# 1    0.9801  in1:1000|hidden:300|out1:100|out2:10--recur:50        s3_network
# 4    0.9804  in1:1000|hidden:300|out1:100|out2:10--recur:50        s3_network
# 2    0.9766    in1:800|hidden:200|out1:70|out2:10--recur:50        s3_network
#
#    batch  column_at_a_time  dims  epoch                   experiment_name  \
# 6     50                 4    28    100   s3-seq-7---2017-11-09--23-46-09
# 3     50                 7    28    100   s3-seq-4---2017-11-09--21-01-27
# 5     50                 7    28    100   s3-seq-4---2017-11-09--22-03-34
# 1     50                 2    28    100  s3-seq-14---2017-11-11--16-39-51
# ...

# %%
df = experiment_artifact.get_results('../experiment-results/sprint-8-no-dropout-rr')\
    .sort_values(by='accuracy', ascending=False)
    
df[ (df.seq_length == 7) & (df.architecture_name == 's3_network')]
# Out:
#     accuracy                                    architecture  \
# 49    0.9789  in1:250|hidden:500|out1:250|out2:10--recur:250
# 50    0.9780  in1:250|hidden:500|out1:250|out2:10--recur:250
# 47    0.9770  in1:250|hidden:500|out1:250|out2:10--recur:250
# 45    0.9766  in1:250|hidden:500|out1:250|out2:10--recur:250
# 48    0.9733  in1:250|hidden:500|out1:250|out2:10--recur:250
# 40    0.9693  in1:250|hidden:500|out1:250|out2:10--recur:250
# 46    0.9693  in1:250|hidden:500|out1:250|out2:10--recur:250
# 39    0.9685  in1:250|hidden:500|out1:250|out2:10--recur:250
# 41    0.9605  in1:250|hidden:500|out1:250|out2:10--recur:250
# 44    0.9601  in1:250|hidden:500|out1:250|out2:10--recur:250
# 42    0.9482  in1:250|hidden:500|out1:250|out2:10--recur:250
# 38    0.9402  in1:250|hidden:500|out1:250|out2:10--recur:250
# 43    0.1135  in1:250|hidden:500|out1:250|out2:10--recur:250
#
#    architecture_name  batch  column_at_a_time  dims  epoch  \
# ...

# %%
df = experiment_artifact.get_results('../experiment-results/sprint-8-bayesian')\
    .sort_values(by='accuracy', ascending=False)
    
df
# Out:
#     accuracy                                    architecture  \
# 6     0.8612  in1:375|hidden:750|out1:375|out2:10--recur:375
# 19    0.8544  in1:375|hidden:750|out1:375|out2:10--recur:375
# 14    0.8536  in1:375|hidden:750|out1:375|out2:10--recur:375
# 17    0.8514  in1:375|hidden:750|out1:375|out2:10--recur:375
# 20    0.8484  in1:375|hidden:750|out1:375|out2:10--recur:375
# 5     0.8484  in1:250|hidden:500|out1:250|out2:10--recur:250
# 7     0.8471  in1:375|hidden:750|out1:375|out2:10--recur:375
# 21    0.8463  in1:375|hidden:750|out1:375|out2:10--recur:375
# 12    0.8452  in1:375|hidden:750|out1:375|out2:10--recur:375
# 3     0.8440  in1:250|hidden:500|out1:250|out2:10--recur:250
# 1     0.8409  in1:250|hidden:500|out1:250|out2:10--recur:250
# 16    0.8394  in1:375|hidden:750|out1:375|out2:10--recur:375
# 18    0.8321  in1:375|hidden:750|out1:375|out2:10--recur:375
# 10    0.8286  in1:375|hidden:750|out1:375|out2:10--recur:375
# ...

# %%
df = experiment_artifact.get_results('../experiment-results/sprint-8-final')\
    .sort_values(by='accuracy', ascending=False)
    
df
# Out:
#    accuracy                                   architecture architecture_name  \
# 2    0.9826  in1:512|hidden:128|out1:64|out2:10--recur:256        s3_network
# 3    0.9822  in1:512|hidden:128|out1:64|out2:10--recur:256        s3_network
# 1    0.9807                   hidden:256|out:10--recur:256        s2_network
# 0    0.9779                   hidden:256|out:10--recur:256        s2_network
#
#    batch  column_at_a_time dataset  dims  epoch  \
# 2     50                 7   mnist    28    100
# 3     50                 4   mnist    28    100
# 1     50                 4   mnist    28    100
# 0     50                 7   mnist    28    100
#
#                          experiment_name  keep_prob      lr  max_seq_length  \
# 2  s3-mnist-seq-4---2017-12-13--14-28-48        0.5  0.0005              28
# 3  s3-mnist-seq-7---2017-12-13--14-46-10        0.5  0.0005              28
# 1  s2-mnist-seq-7---2017-12-13--14-13-10        0.5  0.0005              28
# ...

# %%
df =get_results('../experiment-results/sprint-8-fashion-mnist-100epoch')
    
df
# Out:
#    accuracy                                   architecture architecture_name  \
# 0    0.8877                   hidden:256|out:10--recur:256        s2_network
# 1    0.8752                   hidden:256|out:10--recur:256        s2_network
# 3    0.8729  in1:512|hidden:128|out1:64|out2:10--recur:256        s3_network
# 2    0.8707                   hidden:256|out:10--recur:256        s2_network
# 4    0.8706  in1:512|hidden:128|out1:64|out2:10--recur:256        s3_network
# 5    0.8604  in1:512|hidden:128|out1:64|out2:10--recur:256        s3_network
#
#    batch  column_at_a_time        dataset  dims  epoch  \
# 0     50                28  fashion-mnist    28    100
# 1     50                 7  fashion-mnist    28    100
# 3     50                28  fashion-mnist    28    100
# 2     50                 4  fashion-mnist    28    100
# 4     50                 7  fashion-mnist    28    100
# 5     50                 4  fashion-mnist    28    100
#
# ...

# %% [markdown]
# # Sprint 9th

# %%
df = get_results('../experiment-results/sprint-9')
    
df[df.dataset == 'fashion-mnist']
# Out:
#     accuracy  \
# 3     0.9182
# 1     0.8888
# 0     0.8843
# 4     0.8831
# 2     0.8808
# 14    0.8724
# 12    0.8716
# 13    0.8570
# 20    0.8561
# 15    0.8496
# 11    0.8425
# 19    0.8390
# 16    0.8363
# 9     0.7823
# 10    0.7488
# 17    0.7151
# 18    0.7019
#
#                                                              architecture  \
# 3   conv1:5x5x32=>2x2[2,2]|conv2:5x5x64=>2x2[2,2]|hidden:1024|out1:256...
# 1   conv1:5x5x12=>2x2[2,2]|conv2:5x5x20=>2x2[2,2]|hidden:1024|out1:32|...
# 0   conv1:5x5x12=>2x2[2,2]|conv2:5x5x20=>2x2[2,2]|hidden:1024|out1:32|...
# 4   conv1:5x5x32=>2x2[2,2]|conv2:5x5x64=>2x2[2,2]|hidden:1024|out1:256...
# 2   conv1:5x5x12=>2x2[2,2]|conv2:5x5x20=>2x2[2,2]|hidden:1024|out1:256...
# 14                   in1:1024|in2:256|hidden:128|out1:64|out2:10--recur:1
# 12                    in1:512|in2:256|hidden:128|out1:64|out2:10--recur:8
# 13                    in1:512|in2:256|hidden:128|out1:64|out2:10--recur:8
# ...

# %%
pd.set_option('display.max_colwidth', 70)

# %%
df = get_results('../experiment-results/sprint-9-convdeep')
df['experiment_name']
# Out:
# 2            convdeep_4l_network-mnist-seq-1---2017-12-21--11-29-57
# 3            convdeep_4l_network-mnist-seq-4---2017-12-21--13-28-21
# 0    convdeep_4l_network-fashion-mnist-seq-1---2017-12-21--15-16-08
# 1    convdeep_4l_network-fashion-mnist-seq-4---2017-12-21--17-14-15
# Name: experiment_name, dtype: object

# %%
df = get_results('../experiment-results/sprint-9-deep-4l')
df
# Out:
#    accuracy                                           architecture  \
# 3    0.9806  in1:512|in2:256|hidden:128|out1:64|out2:10--recur:256
# 2    0.9666  in1:512|in2:256|hidden:128|out1:64|out2:10--recur:256
# 0    0.8819  in1:512|in2:256|hidden:128|out1:64|out2:10--recur:256
# 1    0.8669  in1:512|in2:256|hidden:128|out1:64|out2:10--recur:256
#
#   architecture_name  batch  column_at_a_time        dataset  dims  epoch  \
# 3   deep_4l_network     50                 7          mnist    28    100
# 2   deep_4l_network     50                28          mnist    28    100
# 0   deep_4l_network     50                28  fashion-mnist    28    100
# 1   deep_4l_network     50                 7  fashion-mnist    28    100
#
#                                               experiment_name  keep_prob  \
# 3          deep_4l_network-mnist-seq-4---2017-12-22--01-15-16        0.5
# 2          deep_4l_network-mnist-seq-1---2017-12-22--00-44-47        0.5
# ...

# %%
get_results('../experiment-results/sprint-9-s2-final')
# Out:
#    accuracy                  architecture architecture_name  batch  \
# 1    0.9811  hidden:768|out:10--recur:128        s2_network     50
# 2    0.9811  hidden:768|out:10--recur:128        s2_network     50
# 0    0.9805  hidden:768|out:10--recur:128        s2_network     50
# 3    0.9797  hidden:768|out:10--recur:128        s2_network     50
#
#    column_at_a_time dataset  dims  epoch  \
# 1                28   mnist    28    100
# 2                 7   mnist    28    100
# 0                28   mnist    28    100
# 3                 4   mnist    28    100
#
#                                  experiment_name  keep_prob      lr  \
# 1  s2_network-mnist-seq-1---2017-12-29--19-32-53        0.5  0.0001
# 2  s2_network-mnist-seq-4---2017-12-29--20-11-24        0.5  0.0001
# 0  s2_network-mnist-seq-1---2017-12-29--18-40-38        0.5  0.0001
# 3  s2_network-mnist-seq-7---2017-12-29--20-46-01        0.5  0.0001
#
#    max_seq_length      optimizer  regularizer  seq_length  val_accuracy
# ...
