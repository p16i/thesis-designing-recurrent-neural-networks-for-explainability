# %%
# %matplotlib inline
import logging
from utils import logging as lg
lg.set_logging(logging.ERROR)

from scipy import stats
from skimage.measure import block_reduce
import numpy as np

import logging

import pandas as pd
import pickle
from notebook_utils import plot 
import seaborn as sns
import glob
sns.set(color_codes=True, font_scale=2, style="whitegrid", palette="bright")

from model import base, provider, heatmap_evaluation
import config
import matplotlib.pyplot as plt
import tensorflow as tf
import yaml
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
def hypothesis_testing(base, model_paths, methods=['sensitivity', 'guided_backprop', 'lrp_deep_taylor', 'lrp_alpha1_5_beta_5'],
                       significance_level=0.025, metric_name='adjusted_rel_dist_in_data_region'):

    def highlight(s):
        return ['font-weight: bold' if v < significance_level else '' for v in s]

    results = []
    print('paired t-test p value against `%s` architecture\n highlighted when the value <= %f' % (base, significance_level))
    df = plot.get_stats_from_models(model_paths)

    architectures = set(df.architecture.values)
    
    models = list(filter(lambda x: x != base, set(df.architecture.values)))
    for m in models: 
        dd = [('architecture', m)]
        for med in methods:
            baseline = df[(df.architecture == base) & (df.method==med)][metric_name]
            comparing_model = df[(df.architecture == m) & (df.method==med)][metric_name]
            s = stats.ttest_rel(comparing_model, baseline)
            pv = s.pvalue/2.0
            if s.statistic < 0 :
                pv = 1-pv
            dd.append((med, pv))
        results.append(dict(dd))
        
    df_res = pd.DataFrame(results)[['architecture'] + methods].style.apply(highlight, subset=methods)
    return df_res


exp2_models = [
    '../final-models-group/shallow-m*-maj-seq-12-fold-*',
    '../final-models-group/shallow-f*-maj-seq-12-fold-*',

    '../final-models-group/deep-*-maj-seq-12-fold-*',
    '../final-models-group/deep_v2-*-maj-seq-12-fold-*',
    '../final-models-group/convdeep-*-maj-seq-12-fold-*',

]
hypothesis_testing(base='shallow', model_paths=exp2_mnist_models)
# Out:
# paired t-test p value against `shallow` architecture
#  highlighted when the value <= 0.025000
# <style  type="text/css" >
#     #T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow0_col3 {
#             font-weight:  bold;
#         }    #T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow0_col4 {
#             font-weight:  bold;
#         }    #T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow1_col1 {
#             font-weight:  bold;
#         }    #T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow1_col2 {
#             font-weight:  bold;
#         }    #T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow1_col3 {
#             font-weight:  bold;
#         }    #T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow1_col4 {
#             font-weight:  bold;
#         }    #T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow2_col1 {
#             font-weight:  bold;
#         }    #T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow2_col3 {
#             font-weight:  bold;
#         }    #T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow2_col4 {
#             font-weight:  bold;
#         }</style>
# <table id="T_61e9c5da_3141_11e8_b25d_f45c89a76edf" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >architecture</th>
#         <th class="col_heading level0 col1" >sensitivity</th>
#         <th class="col_heading level0 col2" >guided_backprop</th>
#         <th class="col_heading level0 col3" >lrp_deep_taylor</th>
#         <th class="col_heading level0 col4" >lrp_alpha1_5_beta_5</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_61e9c5da_3141_11e8_b25d_f45c89a76edflevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow0_col0" class="data row0 col0" >deep</td>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow0_col1" class="data row0 col1" >0.0535348</td>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow0_col2" class="data row0 col2" >0.451833</td>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow0_col3" class="data row0 col3" >2.31764e-11</td>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow0_col4" class="data row0 col4" >3.94069e-11</td>
#     </tr>    <tr>
#         <th id="T_61e9c5da_3141_11e8_b25d_f45c89a76edflevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow1_col0" class="data row1 col0" >convdeep</td>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow1_col1" class="data row1 col1" >0.000380304</td>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow1_col2" class="data row1 col2" >0.0226089</td>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow1_col3" class="data row1 col3" >5.00673e-13</td>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow1_col4" class="data row1 col4" >1.42664e-11</td>
#     </tr>    <tr>
#         <th id="T_61e9c5da_3141_11e8_b25d_f45c89a76edflevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow2_col0" class="data row2 col0" >deep_v2</td>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow2_col1" class="data row2 col1" >0.0034859</td>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow2_col2" class="data row2 col2" >0.117182</td>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow2_col3" class="data row2 col3" >1.31124e-13</td>
#         <td id="T_61e9c5da_3141_11e8_b25d_f45c89a76edfrow2_col4" class="data row2 col4" >7.94346e-12</td>
#     </tr></tbody>
# </table>

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
def pair_tests(models, methods=['sensitivity', 'guided_backprop', 'lrp_deep_taylor', 'lrp_alpha1_5_beta_5'], alpha=0.01):
    df = plot.get_stats_from_models(models)
    for m in methods:
        df_method = df.loc[df['method'] == m]
        df_removed_na = df_method.dropna()
        print('### Testing for method %s ###' % m)
        print("Have %d/%d rows after removing nan" % (len(df_removed_na), len(df_method)))
        print('='*20, 'ANOVA', '='*20)
        mod = ols('rel_dist_in_data_region ~ architecture', data=df_removed_na).fit()
        aov_table = sm.stats.anova_lm(mod, typ=2)
        print(aov_table)
        esq_sm = aov_table['sum_sq'][0]/(aov_table['sum_sq'][0]+aov_table['sum_sq'][1])
        print('effective size(eta squared) : %f' % esq_sm)
        print('-'*50)
        mc = MultiComparison(    df_removed_na['adjusted_rel_dist_in_data_region'],     df_removed_na['architecture'])
        result = mc.tukeyhsd(alpha=alpha)
        print(result.summary())
        print('\n')

# %%
pair_tests(exp2_models)
# Out:
# ### Testing for method sensitivity ###
# Have 56/56 rows after removing nan
# ==================== ANOVA ====================
#                 sum_sq    df          F        PR(>F)
# architecture  0.055717   3.0  21.132725  4.379611e-09
# Residual      0.045700  52.0        NaN           NaN
# effective size(eta squared) : 0.549386
# --------------------------------------------------
# Multiple Comparison of Means - Tukey HSD,FWER=0.01
# ================================================
#  group1   group2 meandiff  lower   upper  reject
# ------------------------------------------------
# convdeep   deep  -0.0353  -0.0582 -0.0124  True
# convdeep deep_v2 -0.0191   -0.042  0.0039 False
# convdeep shallow  -0.047  -0.0699 -0.0241  True
#   deep   deep_v2  0.0163  -0.0067  0.0392 False
#   deep   shallow -0.0117  -0.0346  0.0112 False
# deep_v2  shallow  -0.028  -0.0509 -0.0051  True
# ------------------------------------------------
#
#
# ### Testing for method guided_backprop ###
# Have 56/56 rows after removing nan
# ==================== ANOVA ====================
#                 sum_sq    df         F    PR(>F)
# architecture  0.014729   3.0  2.383742  0.079826
# Residual      0.107099  52.0       NaN       NaN
# effective size(eta squared) : 0.120897
# --------------------------------------------------
# Multiple Comparison of Means - Tukey HSD,FWER=0.01
# ================================================
#  group1   group2 meandiff  lower   upper  reject
# ------------------------------------------------
# convdeep   deep  -0.0458  -0.0922  0.0005 False
# convdeep deep_v2 -0.0233  -0.0696  0.023  False
# convdeep shallow -0.0482  -0.0945 -0.0019  True
#   deep   deep_v2  0.0226  -0.0238  0.0689 False
#   deep   shallow -0.0024  -0.0487  0.044  False
# deep_v2  shallow -0.0249  -0.0712  0.0214 False
# ------------------------------------------------
#
#
# ### Testing for method lrp_deep_taylor ###
# Have 56/56 rows after removing nan
# ==================== ANOVA ====================
#                 sum_sq    df         F        PR(>F)
# architecture  0.118407   3.0  68.80011  4.128714e-18
# Residual      0.029831  52.0       NaN           NaN
# effective size(eta squared) : 0.798762
# --------------------------------------------------
# Multiple Comparison of Means - Tukey HSD,FWER=0.01
# ================================================
#  group1   group2 meandiff  lower   upper  reject
# ------------------------------------------------
# convdeep   deep   -0.062  -0.0905 -0.0335  True
# convdeep deep_v2 -0.0169  -0.0454  0.0115 False
# convdeep shallow -0.2313  -0.2597 -0.2028  True
#   deep   deep_v2  0.0451   0.0166  0.0735  True
#   deep   shallow -0.1693  -0.1977 -0.1408  True
# deep_v2  shallow -0.2144  -0.2428 -0.1859  True
# ------------------------------------------------
#
#
# ### Testing for method lrp_alpha1_5_beta_5 ###
# Have 56/56 rows after removing nan
# ==================== ANOVA ====================
#                 sum_sq    df          F        PR(>F)
# architecture  0.182721   3.0  68.502508  4.515600e-18
# Residual      0.046234  52.0        NaN           NaN
# effective size(eta squared) : 0.798064
# --------------------------------------------------
# Multiple Comparison of Means - Tukey HSD,FWER=0.01
# ================================================
#  group1   group2 meandiff  lower   upper  reject
# ------------------------------------------------
# convdeep   deep  -0.0344  -0.0651 -0.0036  True
# convdeep deep_v2 -0.0079  -0.0387  0.0228 False
# convdeep shallow -0.2267  -0.2574 -0.1959  True
#   deep   deep_v2  0.0264  -0.0043  0.0572 False
#   deep   shallow -0.1923   -0.223 -0.1616  True
# deep_v2  shallow -0.2187  -0.2495  -0.188  True
# ------------------------------------------------

# %%
deep_vs_lstm_models = [
    '../final-models-group/deep-m*-maj-seq-12-fold-*',
    '../final-models-group/deep-f*-maj-seq-12-fold-*',

    '../final-models-group/deep_persisted_dropout-*-maj-seq-12-fold-*',
    
    
    '../final-models-group/rlstm-*-maj-seq-12-fold-*',
    '../final-models-group/rlstm_persisted_dropout-*-maj-seq-12-fold-*']
pair_tests(deep_vs_lstm_models)
# Out:
# ### Testing for method sensitivity ###
# Have 56/56 rows after removing nan
# ==================== ANOVA ====================
#                 sum_sq    df          F        PR(>F)
# architecture  0.017848   3.0  19.103688  1.753310e-08
# Residual      0.016194  52.0        NaN           NaN
# effective size(eta squared) : 0.524293
# --------------------------------------------------
#               Multiple Comparison of Means - Tukey HSD,FWER=0.01
# =============================================================================
#         group1                  group2         meandiff  lower  upper  reject
# -----------------------------------------------------------------------------
#          deep           deep_persisted_dropout -0.0063  -0.0192 0.0066 False
#          deep                   rlstm           0.0329    0.02  0.0458  True
#          deep          rlstm_persisted_dropout  0.0234   0.0105 0.0363  True
# deep_persisted_dropout          rlstm           0.0392   0.0263 0.0521  True
# deep_persisted_dropout rlstm_persisted_dropout  0.0298   0.0169 0.0427  True
#         rlstm          rlstm_persisted_dropout -0.0095  -0.0224 0.0034 False
# -----------------------------------------------------------------------------
#
#
# ### Testing for method guided_backprop ###
# Have 56/56 rows after removing nan
# ==================== ANOVA ====================
#                 sum_sq    df         F    PR(>F)
# architecture  0.006331   3.0  3.097725  0.034629
# Residual      0.035425  52.0       NaN       NaN
# effective size(eta squared) : 0.151618
# --------------------------------------------------
#               Multiple Comparison of Means - Tukey HSD,FWER=0.01
# =============================================================================
#         group1                  group2         meandiff  lower  upper  reject
# -----------------------------------------------------------------------------
#          deep           deep_persisted_dropout -0.0143  -0.0425 0.0138 False
#          deep                   rlstm           0.0862   0.058  0.1143  True
#          deep          rlstm_persisted_dropout  0.1132   0.085  0.1414  True
# deep_persisted_dropout          rlstm           0.1005   0.0723 0.1287  True
# deep_persisted_dropout rlstm_persisted_dropout  0.1275   0.0994 0.1557  True
#         rlstm          rlstm_persisted_dropout  0.027   -0.0011 0.0552 False
# -----------------------------------------------------------------------------
#
#
# ### Testing for method lrp_deep_taylor ###
# Have 56/56 rows after removing nan
# ==================== ANOVA ====================
#                 sum_sq    df          F        PR(>F)
# architecture  0.020049   3.0  20.811266  5.429840e-09
# Residual      0.016699  52.0        NaN           NaN
# effective size(eta squared) : 0.545589
# --------------------------------------------------
#               Multiple Comparison of Means - Tukey HSD,FWER=0.01
# =============================================================================
#         group1                  group2         meandiff  lower  upper  reject
# -----------------------------------------------------------------------------
#          deep           deep_persisted_dropout -0.0131  -0.0387 0.0125 False
#          deep                   rlstm           0.0755   0.0499 0.1011  True
#          deep          rlstm_persisted_dropout  0.1014   0.0758 0.127   True
# deep_persisted_dropout          rlstm           0.0886   0.063  0.1142  True
# deep_persisted_dropout rlstm_persisted_dropout  0.1145   0.0889 0.1401  True
#         rlstm          rlstm_persisted_dropout  0.0259   0.0003 0.0515  True
# -----------------------------------------------------------------------------
#
#
# ### Testing for method lrp_alpha1_5_beta_5 ###
# Have 56/56 rows after removing nan
# ==================== ANOVA ====================
#                 sum_sq    df           F        PR(>F)
# architecture  0.176544   3.0  132.130458  2.590656e-24
# Residual      0.023160  52.0         NaN           NaN
# effective size(eta squared) : 0.884030
# --------------------------------------------------
#               Multiple Comparison of Means - Tukey HSD,FWER=0.01
# =============================================================================
#         group1                  group2         meandiff  lower  upper  reject
# -----------------------------------------------------------------------------
#          deep           deep_persisted_dropout  -0.027  -0.0511 -0.003  True
#          deep                   rlstm           0.1519   0.1278 0.176   True
#          deep          rlstm_persisted_dropout  0.1836   0.1595 0.2077  True
# deep_persisted_dropout          rlstm           0.1789   0.1549 0.203   True
# deep_persisted_dropout rlstm_persisted_dropout  0.2107   0.1866 0.2347  True
#         rlstm          rlstm_persisted_dropout  0.0317   0.0076 0.0558  True
# -----------------------------------------------------------------------------

# %%
conv_vs_convliteral = [
    '../final-models-group/convdeep-mnist-3-digits-maj-seq-12-fold*',
    '../final-models-group/convdeep-fashion-mnist-3-items-maj-seq-12-fold*',
    '../final-models-group/convdeep_transcribe-*-maj-seq-12-fold*',    
    '../final-models-group/convrlstm_persisted_dropout-*-maj-seq-12-fold*',
    '../final-models-group/convtran_rlstm_persisted_dropout-*-maj-seq-12-fold*',
]

pair_tests(conv_vs_convliteral)
# Out:
# ### Testing for method sensitivity ###
# Have 44/44 rows after removing nan
# ==================== ANOVA ====================
#                 sum_sq    df           F        PR(>F)
# architecture  0.223879   3.0  123.317932  2.994343e-20
# Residual      0.024206  40.0         NaN           NaN
# effective size(eta squared) : 0.902428
# --------------------------------------------------
#                      Multiple Comparison of Means - Tukey HSD,FWER=0.01
# ============================================================================================
#            group1                        group2              meandiff  lower   upper  reject
# --------------------------------------------------------------------------------------------
#           convdeep                convdeep_transcribe        -0.1041  -0.1257 -0.0825  True
#           convdeep            convrlstm_persisted_dropout    -0.0093  -0.0309  0.0123 False
#           convdeep          convtran_rlstm_persisted_dropout -0.0766  -0.1197 -0.0334  True
#     convdeep_transcribe       convrlstm_persisted_dropout     0.0948   0.0732  0.1164  True
#     convdeep_transcribe     convtran_rlstm_persisted_dropout  0.0275  -0.0156  0.0707 False
# convrlstm_persisted_dropout convtran_rlstm_persisted_dropout -0.0673  -0.1104 -0.0241  True
# --------------------------------------------------------------------------------------------
#
#
# ### Testing for method guided_backprop ###
# Have 44/44 rows after removing nan
# ==================== ANOVA ====================
#                 sum_sq    df          F        PR(>F)
# architecture  0.207955   3.0  54.882598  3.071171e-14
# Residual      0.050521  40.0        NaN           NaN
# effective size(eta squared) : 0.804542
# --------------------------------------------------
#                      Multiple Comparison of Means - Tukey HSD,FWER=0.01
# ===========================================================================================
#            group1                        group2              meandiff  lower  upper  reject
# -------------------------------------------------------------------------------------------
#           convdeep                convdeep_transcribe        -0.0637  -0.0985 -0.029  True
#           convdeep            convrlstm_persisted_dropout     0.0926   0.0578 0.1273  True
#           convdeep          convtran_rlstm_persisted_dropout  -0.004  -0.0735 0.0655 False
#     convdeep_transcribe       convrlstm_persisted_dropout     0.1563   0.1215 0.191   True
#     convdeep_transcribe     convtran_rlstm_persisted_dropout  0.0598  -0.0097 0.1293 False
# convrlstm_persisted_dropout convtran_rlstm_persisted_dropout -0.0965   -0.166 -0.027  True
# -------------------------------------------------------------------------------------------
#
#
# ### Testing for method lrp_deep_taylor ###
# Have 44/44 rows after removing nan
# ==================== ANOVA ====================
#                 sum_sq    df          F        PR(>F)
# architecture  0.088226   3.0  63.418625  2.942302e-15
# Residual      0.018549  40.0        NaN           NaN
# effective size(eta squared) : 0.826280
# --------------------------------------------------
#                      Multiple Comparison of Means - Tukey HSD,FWER=0.01
# ============================================================================================
#            group1                        group2              meandiff  lower   upper  reject
# --------------------------------------------------------------------------------------------
#           convdeep                convdeep_transcribe        -0.0721  -0.0949 -0.0493  True
#           convdeep            convrlstm_persisted_dropout     0.0317   0.0089  0.0544  True
#           convdeep          convtran_rlstm_persisted_dropout -0.0032  -0.0487  0.0424 False
#     convdeep_transcribe       convrlstm_persisted_dropout     0.1038   0.081   0.1265  True
#     convdeep_transcribe     convtran_rlstm_persisted_dropout  0.0689   0.0234  0.1145  True
# convrlstm_persisted_dropout convtran_rlstm_persisted_dropout -0.0348  -0.0804  0.0107 False
# --------------------------------------------------------------------------------------------
#
#
# ### Testing for method lrp_alpha1_5_beta_5 ###
# Have 44/44 rows after removing nan
# ==================== ANOVA ====================
#                 sum_sq    df          F        PR(>F)
# architecture  0.385745   3.0  192.41846  8.492751e-24
# Residual      0.026730  40.0        NaN           NaN
# effective size(eta squared) : 0.935197
# --------------------------------------------------
#                      Multiple Comparison of Means - Tukey HSD,FWER=0.01
# ============================================================================================
#            group1                        group2              meandiff  lower   upper  reject
# --------------------------------------------------------------------------------------------
#           convdeep                convdeep_transcribe        -0.0772  -0.1017 -0.0528  True
#           convdeep            convrlstm_persisted_dropout     0.1573   0.1328  0.1817  True
#           convdeep          convtran_rlstm_persisted_dropout  0.0401  -0.0088  0.089  False
#     convdeep_transcribe       convrlstm_persisted_dropout     0.2345    0.21   0.259   True
#     convdeep_transcribe     convtran_rlstm_persisted_dropout  0.1173   0.0684  0.1663  True
# convrlstm_persisted_dropout convtran_rlstm_persisted_dropout -0.1172  -0.1661 -0.0682  True
# --------------------------------------------------------------------------------------------
